# %%
import os
import networkx as nx
import importlib
import logging
import functools
from collections import OrderedDict

import pbsmrtpipe.loader as pbl
import pbsmrtpipe.chunked_models as pbc
import pbsmrtpipe.dag as pbd
import pbsmrtpipe.io as pbio
import pbsmrtpipe.resource_types as pbrt
import pbsmrtpipe.utils as pbu
import pbsmrtpipe.mock as pbm

import pbsmrtpipe.task_modules
from pbsmrtpipe.resource_types import ReferenceEntryType, InputXml, MovieFofn, BaseFileType
from pbsmrtpipe.decos import validate_type
from pbsmrtpipe.models.core import P_Module, MetaTask, MetaFile, FileNode, TaskNode
from pbsmrtpipe.task_modules.core import ChunkedList, BaseGatherTask

# DAG
from pbsmrtpipe.dag import *
from pbsmrtpipe.dag import _get_pb_module_color

import pbsmrtpipe.toolbook as tb

log = logging.getLogger()
#pbu.setup_log(log, level=logging.DEBUG)

# %%
# Need Fetch for the stupid chemistry mapping.xml file
pb_module_names = 'fetch mapping mapping_reports'.split()

task_klasses = pbl.load_tasks_from_pb_module_names(pb_module_names)
abstract_g = pbd.build_abstract_graph_from_task_classes(task_klasses)

# %%
tb.display_networkx_graph(abstract_g)

# %%
pbd.find_required_input_files(abstract_g)
# Out:
# [<MetaFile id 8 file FilteredRegionFofn>,
#  <MetaFile id 20 file FilteredSubreadsFasta>,
#  <MetaFile id 9 file ReferenceEntryType>,
#  <MetaFile id 14 file ChemistryMappingXml>,
#  <MetaFile id 1 file InputXml>]

# %%
input_d = {pbrt.InputXml:"/path/input.xml",
           pbrt.ReferenceEntryType:pbm.get_reference_dir(),
           pbrt.FilteredRegionFofn:'/path/to/filtered_region.fofn',
           pbrt.FilteredSubreadsFasta:'/path/to/filtered_subreads.fasta'}

workflow_settings = pbm.get_mapping_workflow_settings()
# Out:
# WARNING:pbsmrtpipe.io:ALGO_PARAMS key not found in smrtpipe.rc - using latest bundle: /Users/mkocher/gh_projects/pbsmrtpipe/notebooks/MOCK_SEYMOUR_HOME/analysis/etc/algorithm_parameters/2013-03

# %%
task_klasses
# Out:
# [pbsmrtpipe.task_modules.fetch.ToFofnTask,
#  pbsmrtpipe.task_modules.fetch.OverViewTask,
#  pbsmrtpipe.task_modules.fetch.AdapterReportTask,
#  pbsmrtpipe.task_modules.mapping.MappingAlignTask,
#  pbsmrtpipe.task_modules.mapping.MappingSortTask,
#  pbsmrtpipe.task_modules.mapping.MappingLoadChemistryTask,
#  pbsmrtpipe.task_modules.mapping.MappingSamBamTask,
#  pbsmrtpipe.task_modules.mapping.MappingUnmappedTask,
#  pbsmrtpipe.task_modules.mapping.CoverageGffTask,
#  pbsmrtpipe.task_modules.mapping.GffToBedTask,
#  pbsmrtpipe.task_modules.mapping_reports.MappingStatsReportTask,
#  pbsmrtpipe.task_modules.mapping_reports.MappingCoverageReportTask]

# %%
print workflow_settings
# Out:
# WorkflowSettings Summary
#            chunked : False
#        distributed : False
#          max_slots : 8
#        max_workers : 6
#            tmp_dir : /scratch
#              nproc : 4
#             job_id : 123456
#              debug : True
#     job_output_dir : /tmp/mock_job
#   ALGO_PARAMS_PATH : /Users/mkocher/gh_projects/pbsmrtpipe/notebooks/MOCK_SEYMOUR_HOME/analysis/etc/algorithm_parameters/2013-03
#     INPUT_HDF5_EXT : bas.h5

# %%
print workflow_settings.summary()
# Out:
# WorkflowSettings Summary
#            chunked : False
#        distributed : False
#          max_slots : 8
#        max_workers : 6
#            tmp_dir : /scratch
#              nproc : 4
#             job_id : 123456
#              debug : True
#     job_output_dir : /tmp/mock_job
#   ALGO_PARAMS_PATH : /Users/mkocher/gh_projects/pbsmrtpipe/notebooks/MOCK_SEYMOUR_HOME/analysis/etc/algorithm_parameters/2013-03
#     INPUT_HDF5_EXT : bas.h5
#
# Module Parameters
# ********************
# module scope: filter
# ********************
#                  filters : MinRL=50,MinReadScore=0.65
#                     trim : True
# ********************
# module scope: global
# ********************
#             use_subreads : True
#                reference : /mnt/secondary-siv/references/ecoli_k12_MG1655
#               noise.data : -77.27,0.08654,0.00121
# *********************
# module scope: mapping
# *********************
#                   samBam : True
#             pulseMetrics : DeletionQV,IPD,InsertionQV,PulseWidth,QualityValue,MergeQV,SubstitutionQV,DeletionTag
#                  gff2Bed : True
#           loadPulsesOpts : bymetric
#               concordant : True
#                  maxHits : 10
#             pbalign_opts : --seed=1 --minAccuracy=0.75 --minLength=50 --algorithmOptions="-useQuality"
#            minAnchorSize : 12
#            maxDivergence : 30
#     placeRepeatsRandomly : True

# %%
#print task_klasses
tc =task_klasses[-4]
print tc
print tc._OPTIONS
# Out:
# <class 'pbsmrtpipe.task_modules.mapping.CoverageGffTask'>
# {'numCoverageRegions': <IntOption name:num_stats_regions type:<type 'int'> default_value:500 optional? True >}

# %%
output_dir = "/path/to/output_dir"
resolved_g = pbd.build_resolved_graph(abstract_g, input_d, workflow_settings)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-4d273843922d> in <module>()
#       1 output_dir = "/path/to/output_dir"
# ----> 2 resolved_g = pbd.build_resolved_graph(abstract_g, input_d, workflow_settings)
#
# /Users/mkocher/.virtualenvs/dev_pbsmrtpipe/lib/python2.7/site-packages/pbsmrtpipe/dag.pyc in build_resolved_graph(g, inputs_d, workflow_settings)
#     285     for required_input in required_input_klasses:
#     286         if required_input not in inputs_d:
# --> 287             raise ValueError("Required input {i} not found for abstract graph in supplied inputs_d {s}.".format(i=required_input, s=inputs_d))
#     288
#     289     # Stupid Simple mapping of MetaTask -> TaskNode, MetaFile -> FileNode
#
# ValueError: Required input <class 'pbsmrtpipe.resource_types.ChemistryMappingXml'> not found for abstract graph in supplied inputs_d {<class 'pbsmrtpipe.resource_types.ReferenceEntryType'>: '/common/references/ecoli_k12_MG1655', <class 'pbsmrtpipe.resource_types.FilteredSubreadsFasta'>: '/path/to/filtered_subreads.fasta', <class 'pbsmrtpipe.resource_types.InputXml'>: '/path/input.xml', <class 'pbsmrtpipe.resource_types.FilteredRegionFofn'>: '/path/to/filtered_region.fofn'}.

# %%
tb.display_networkx_graph(resolved_g)
