# %%
import os
import networkx as nx
import importlib
import logging
import functools
from collections import OrderedDict

import pbsmrtpipe.loader as pbl
import pbsmrtpipe.chunked_models as pbc
import pbsmrtpipe.dag as pbd
import pbsmrtpipe.io as pbio
import pbsmrtpipe.resource_types as pbrt
import pbsmrtpipe.utils as pbu
import pbsmrtpipe.mock

import pbsmrtpipe.task_modules
from pbsmrtpipe.resource_types import ReferenceEntryType, InputXml, MovieFofn, BaseFileType
from pbsmrtpipe.decos import validate_type
from pbsmrtpipe.model import P_Module, MetaTask, MetaFile, FileNode, TaskNode
from pbsmrtpipe.task_modules.core import ChunkedList, BaseGatherTask

import pbsmrtpipe.toolbook as tb

log = logging.getLogger()
pbu.setup_log(log, level=logging.DEBUG)

# %%
# this is essentially HGAP2
pb_module_names = ['preassembler_dagcon', 
                   'mapping', 
                   'assembly_polishing', 
                   'mapping_reports', 
                   'filter', 'filter_reports',
                   'fetch']

task_klasses = pbl.load_tasks_from_pb_module_names(pb_module_names)
abstract_g = pbd.build_abstract_graph_from_task_classes(task_klasses)

# %%
pbd.find_required_input_files(abstract_g)
# Out:
# [<MetaFile id 74 file InputXml>,
#  <MetaFile id 49 file PolishedAlignmentGff>,
#  <MetaFile id 17 file PacBioToCASemFrgLoaded>,
#  <MetaFile id 23 file PacBioToCASem>]

# %%
tb.display_networkx_graph(abstract_g)
# Out:
# DEBUG:pbsmrtpipe.engine:Running on Michaels-MacBook-Pro.local with cmd 'dot -Tsvg /var/folders/_c/8_r02r4s7vl3kx1pt92sbcmr0000gn/T/tmpESYLMd.dot -o /var/folders/_c/8_r02r4s7vl3kx1pt92sbcmr0000gn/T/tmpYWzEU4.svg'
# [DEBUG] 2014-02-05 16:33:14,804 [pbsmrtpipe.engine backticks 39] Running on Michaels-MacBook-Pro.local with cmd 'dot -Tsvg /var/folders/_c/8_r02r4s7vl3kx1pt92sbcmr0000gn/T/tmpESYLMd.dot -o /var/folders/_c/8_r02r4s7vl3kx1pt92sbcmr0000gn/T/tmpYWzEU4.svg'
# DEBUG:pbsmrtpipe.engine:Successful output (Return code = 0) in 1.30 sec (0.02 min) of dot -Tsvg /var/folders/_c/8_r02r4s7vl3kx1pt92sbcmr0000gn/T/tmpESYLMd.dot -o /var/folders/_c/8_r02r4s7vl3kx1pt92sbcmr0000gn/T/tmpYWzEU4.svg
# [DEBUG] 2014-02-05 16:33:14,806 [pbsmrtpipe.engine backticks 60] Successful output (Return code = 0) in 1.30 sec (0.02 min) of dot -Tsvg /var/folders/_c/8_r02r4s7vl3kx1pt92sbcmr0000gn/T/tmpESYLMd.dot -o /var/folders/_c/8_r02r4s7vl3kx1pt92sbcmr0000gn/T/tmpYWzEU4.svg

# %%
workflow_settings = pbsmrtpipe.mock.get_hgap2_workflow_settings()
# Out:
# INFO:pbsmrtpipe.io:ALGO_PARAMS key not found in smrtpipe.rc - using latest bundle: /Users/mkocher/MOCK_SEYMOUR_HOME/analysis/etc/algorithm_parameters/2013-09
# [INFO] 2014-02-05 16:33:16,401 [pbsmrtpipe.io get_algorithm_parameters_path 62] ALGO_PARAMS key not found in smrtpipe.rc - using latest bundle: /Users/mkocher/MOCK_SEYMOUR_HOME/analysis/etc/algorithm_parameters/2013-09

# %%
required_task_klasses = [i.file_klass for i in pbd.find_required_input_files(abstract_g)]
inputs_d = {i.__class__:i.path for i in pbsmrtpipe.mock.generate_mock_files_from_klasses(required_task_klasses, workflow_settings.job_output_dir)}
# Overwrite with real reference
inputs_d[ReferenceEntryType] = pbsmrtpipe.mock.get_reference_dir()
inputs_d
# Out:
# {pbsmrtpipe.resource_types.InputXml: '/tmp/mock_job/input.xml',
#  pbsmrtpipe.resource_types.ReferenceEntryType: '/Users/mkocher/MOCK_SEYMOUR_HOME/common/references/ecoli_k12_MG1655',
#  pbsmrtpipe.resource_types.PacBioToCASem: '/tmp/mock_job/pacBioToCA.sem',
#  pbsmrtpipe.resource_types.PacBioToCASemFrgLoaded: '/tmp/mock_job/pacBioToCAFrgLoad.sem',
#  pbsmrtpipe.resource_types.PolishedAlignmentGff: '/tmp/mock_job/alignment_summary.gff'}

# %%
resolved_graph = pbd.build_resolved_graph(abstract_g, inputs_d, workflow_settings)
# Out:
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 18 file RunCeleraAssemblerSpec to FileNode(18, /tmp/mock_job/runCA.spec) FileKlass RunCeleraAssemblerSpec
# [INFO] 2014-02-05 16:33:18,873 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 18 file RunCeleraAssemblerSpec to FileNode(18, /tmp/mock_job/runCA.spec) FileKlass RunCeleraAssemblerSpec
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 34 file SortedAlignedCmph5WithChemistry to FileNode(34, /tmp/mock_job/aligned_reads.cmp.h5) FileKlass SortedAlignedCmph5WithChemistry
# [INFO] 2014-02-05 16:33:18,874 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 34 file SortedAlignedCmph5WithChemistry to FileNode(34, /tmp/mock_job/aligned_reads.cmp.h5) FileKlass SortedAlignedCmph5WithChemistry
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 47 file PolishedAssemblyFastqGzipped to FileNode(47, /tmp/mock_job/polished_assembly.fastq.gz) FileKlass PolishedAssemblyFastqGzipped
# [INFO] 2014-02-05 16:33:18,875 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 47 file PolishedAssemblyFastqGzipped to FileNode(47, /tmp/mock_job/polished_assembly.fastq.gz) FileKlass PolishedAssemblyFastqGzipped
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 58 file MappingStatsReport to FileNode(58, /tmp/mock_job/mapping_stats_report.json) FileKlass MappingStatsReport
# [INFO] 2014-02-05 16:33:18,876 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 58 file MappingStatsReport to FileNode(58, /tmp/mock_job/mapping_stats_report.json) FileKlass MappingStatsReport
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 56 file PolishedAssemblyReport to FileNode(56, /tmp/mock_job/corrections.json) FileKlass PolishedAssemblyReport
# [INFO] 2014-02-05 16:33:18,876 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 56 file PolishedAssemblyReport to FileNode(56, /tmp/mock_job/corrections.json) FileKlass PolishedAssemblyReport
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 49 file PolishedAlignmentGff to FileNode(49, /tmp/mock_job/alignment_summary.gff) FileKlass PolishedAlignmentGff
# [INFO] 2014-02-05 16:33:18,877 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 49 file PolishedAlignmentGff to FileNode(49, /tmp/mock_job/alignment_summary.gff) FileKlass PolishedAlignmentGff
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 64 file FilteredSubreadsFastq to FileNode(64, /tmp/mock_job/filtered_subreads.fastq) FileKlass FilteredSubreadsFastq
# [INFO] 2014-02-05 16:33:18,877 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 64 file FilteredSubreadsFastq to FileNode(64, /tmp/mock_job/filtered_subreads.fastq) FileKlass FilteredSubreadsFastq
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 4 file BlasrM4 to FileNode(4, /tmp/mock_job/seeds.m4) FileKlass BlasrM4
# [INFO] 2014-02-05 16:33:18,878 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 4 file BlasrM4 to FileNode(4, /tmp/mock_job/seeds.m4) FileKlass BlasrM4
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 31 file SortedAlignedCmph5 to FileNode(31, /tmp/mock_job/aligned_reads.cmp.h5) FileKlass SortedAlignedCmph5
# [INFO] 2014-02-05 16:33:18,878 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 31 file SortedAlignedCmph5 to FileNode(31, /tmp/mock_job/aligned_reads.cmp.h5) FileKlass SortedAlignedCmph5
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 25 file CorrectedReadsFrg to FileNode(25, /tmp/mock_job/corrected.frg) FileKlass CorrectedReadsFrg
# [INFO] 2014-02-05 16:33:18,879 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 25 file CorrectedReadsFrg to FileNode(25, /tmp/mock_job/corrected.frg) FileKlass CorrectedReadsFrg
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 9 file CorrectedFasta to FileNode(9, /tmp/mock_job/corrected.fasta) FileKlass CorrectedFasta
# [INFO] 2014-02-05 16:33:18,879 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 9 file CorrectedFasta to FileNode(9, /tmp/mock_job/corrected.fasta) FileKlass CorrectedFasta
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 10 file CorrectedFastq to FileNode(10, /tmp/mock_job/corrected.fastq) FileKlass CorrectedFastq
# [INFO] 2014-02-05 16:33:18,880 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 10 file CorrectedFastq to FileNode(10, /tmp/mock_job/corrected.fastq) FileKlass CorrectedFastq
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 39 file UnmappedSubreadsFasta to FileNode(39, /tmp/mock_job/unmapped_subreads.fasta) FileKlass UnmappedSubreadsFasta
# [INFO] 2014-02-05 16:33:18,880 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 39 file UnmappedSubreadsFasta to FileNode(39, /tmp/mock_job/unmapped_subreads.fasta) FileKlass UnmappedSubreadsFasta
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 46 file PolishedAssemblyFasta to FileNode(46, /tmp/mock_job/polished_assembly.fasta) FileKlass PolishedAssemblyFasta
# [INFO] 2014-02-05 16:33:18,881 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 46 file PolishedAssemblyFasta to FileNode(46, /tmp/mock_job/polished_assembly.fasta) FileKlass PolishedAssemblyFasta
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 52 file VariantsReport to FileNode(52, /tmp/mock_job/variants_report.json) FileKlass VariantsReport
# [INFO] 2014-02-05 16:33:18,881 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 52 file VariantsReport to FileNode(52, /tmp/mock_job/variants_report.json) FileKlass VariantsReport
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 41 file MappingAlignmentSummaryGff to FileNode(41, /tmp/mock_job/alignment_summary.gff) FileKlass MappingAlignmentSummaryGff
# [INFO] 2014-02-05 16:33:18,882 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 41 file MappingAlignmentSummaryGff to FileNode(41, /tmp/mock_job/alignment_summary.gff) FileKlass MappingAlignmentSummaryGff
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 37 file MappingBam to FileNode(37, /tmp/mock_job/aligned_reads.bam) FileKlass MappingBam
# [INFO] 2014-02-05 16:33:18,882 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 37 file MappingBam to FileNode(37, /tmp/mock_job/aligned_reads.bam) FileKlass MappingBam
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 54 file PolishedTopCorrectionsReport to FileNode(54, /tmp/mock_job/top_corrections_report.json) FileKlass PolishedTopCorrectionsReport
# [INFO] 2014-02-05 16:33:18,883 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 54 file PolishedTopCorrectionsReport to FileNode(54, /tmp/mock_job/top_corrections_report.json) FileKlass PolishedTopCorrectionsReport
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 1 file FilteredSubreadsFasta to FileNode(1, /tmp/mock_job/filtered_subreads.fasta) FileKlass FilteredSubreadsFasta
# [INFO] 2014-02-05 16:33:18,883 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 1 file FilteredSubreadsFasta to FileNode(1, /tmp/mock_job/filtered_subreads.fasta) FileKlass FilteredSubreadsFasta
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 62 file FilterSummaryCsv to FileNode(62, /tmp/mock_job/filter_summary.csv) FileKlass FilterSummaryCsv
# [INFO] 2014-02-05 16:33:18,883 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 62 file FilterSummaryCsv to FileNode(62, /tmp/mock_job/filter_summary.csv) FileKlass FilterSummaryCsv
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 45 file PolishedCorrectionsGff to FileNode(45, /tmp/mock_job/corrections.gff) FileKlass PolishedCorrectionsGff
# [INFO] 2014-02-05 16:33:18,884 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 45 file PolishedCorrectionsGff to FileNode(45, /tmp/mock_job/corrections.gff) FileKlass PolishedCorrectionsGff
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 29 file AlignedCmph5 to FileNode(29, /tmp/mock_job/aligned_reads.cmp.h5) FileKlass AlignedCmph5
# [INFO] 2014-02-05 16:33:18,884 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 29 file AlignedCmph5 to FileNode(29, /tmp/mock_job/aligned_reads.cmp.h5) FileKlass AlignedCmph5
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 28 file FilteredRegionFofn to FileNode(28, /tmp/mock_job/filtered_region.fofn) FileKlass FilteredRegionFofn
# [INFO] 2014-02-05 16:33:18,885 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 28 file FilteredRegionFofn to FileNode(28, /tmp/mock_job/filtered_region.fofn) FileKlass FilteredRegionFofn
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 19 file CeleraAssemblerAsm to FileNode(19, /tmp/mock_job/celera-assembler.asm) FileKlass CeleraAssemblerAsm
# [INFO] 2014-02-05 16:33:18,885 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 19 file CeleraAssemblerAsm to FileNode(19, /tmp/mock_job/celera-assembler.asm) FileKlass CeleraAssemblerAsm
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 2 file FilteredLongReadsFasta to FileNode(2, /tmp/mock_job/"filtered_longreads.fasta") FileKlass FilteredLongReadsFasta
# [INFO] 2014-02-05 16:33:18,886 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 2 file FilteredLongReadsFasta to FileNode(2, /tmp/mock_job/"filtered_longreads.fasta") FileKlass FilteredLongReadsFasta
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 7 file FilteredBlasrM4 to FileNode(7, /tmp/mock_job/seeds.m4.filter) FileKlass FilteredBlasrM4
# [INFO] 2014-02-05 16:33:18,886 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 7 file FilteredBlasrM4 to FileNode(7, /tmp/mock_job/seeds.m4.filter) FileKlass FilteredBlasrM4
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 20 file AssemblyDegFasta to FileNode(20, /tmp/mock_job/celera-assembler.deg.fasta) FileKlass AssemblyDegFasta
# [INFO] 2014-02-05 16:33:18,887 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 20 file AssemblyDegFasta to FileNode(20, /tmp/mock_job/celera-assembler.deg.fasta) FileKlass AssemblyDegFasta
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 36 file MappingSam to FileNode(36, /tmp/mock_job/aligned_reads.sam) FileKlass MappingSam
# [INFO] 2014-02-05 16:33:18,887 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 36 file MappingSam to FileNode(36, /tmp/mock_job/aligned_reads.sam) FileKlass MappingSam
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 43 file MappingCoverageBed to FileNode(43, /tmp/mock_job/coverage.bed) FileKlass MappingCoverageBed
# [INFO] 2014-02-05 16:33:18,888 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 43 file MappingCoverageBed to FileNode(43, /tmp/mock_job/coverage.bed) FileKlass MappingCoverageBed
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 70 file FilterLoadingReport to FileNode(70, /tmp/mock_job/filter_reports_loading.json) FileKlass FilterLoadingReport
# [INFO] 2014-02-05 16:33:18,888 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 70 file FilterLoadingReport to FileNode(70, /tmp/mock_job/filter_reports_loading.json) FileKlass FilterLoadingReport
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 5 file BlasrM4Fofn to FileNode(5, /tmp/mock_job/seeds.m4.fofn) FileKlass BlasrM4Fofn
# [INFO] 2014-02-05 16:33:18,889 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 5 file BlasrM4Fofn to FileNode(5, /tmp/mock_job/seeds.m4.fofn) FileKlass BlasrM4Fofn
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 12 file PreAssemblerReport to FileNode(12, /tmp/mock_job/preassembler_report.json) FileKlass PreAssemblerReport
# [INFO] 2014-02-05 16:33:18,889 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 12 file PreAssemblerReport to FileNode(12, /tmp/mock_job/preassembler_report.json) FileKlass PreAssemblerReport
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 50 file PolishedAlignmentWithVariantsGff to FileNode(50, /tmp/mock_job/alignment_summary.gff) FileKlass PolishedAlignmentWithVariantsGff
# [INFO] 2014-02-05 16:33:18,890 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 50 file PolishedAlignmentWithVariantsGff to FileNode(50, /tmp/mock_job/alignment_summary.gff) FileKlass PolishedAlignmentWithVariantsGff
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 79 file AdapterJsonReport to FileNode(79, /tmp/mock_job/adapter_report.json) FileKlass AdapterJsonReport
# [INFO] 2014-02-05 16:33:18,890 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 79 file AdapterJsonReport to FileNode(79, /tmp/mock_job/adapter_report.json) FileKlass AdapterJsonReport
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 68 file FilterJsonReport to FileNode(68, /tmp/mock_job/filter_report.json) FileKlass FilterJsonReport
# [INFO] 2014-02-05 16:33:18,891 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 68 file FilterJsonReport to FileNode(68, /tmp/mock_job/filter_report.json) FileKlass FilterJsonReport
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 14 file AssemblyScfFasta to FileNode(14, /tmp/mock_job/celera-assembler.scf.fasta) FileKlass AssemblyScfFasta
# [INFO] 2014-02-05 16:33:18,891 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 14 file AssemblyScfFasta to FileNode(14, /tmp/mock_job/celera-assembler.scf.fasta) FileKlass AssemblyScfFasta
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 33 file ChemistryMappingXml to FileNode(33, /tmp/mock_job/chemistry_mapping.xml) FileKlass ChemistryMappingXml
# [INFO] 2014-02-05 16:33:18,892 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 33 file ChemistryMappingXml to FileNode(33, /tmp/mock_job/chemistry_mapping.xml) FileKlass ChemistryMappingXml
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 74 file InputXml to FileNode(74, /tmp/mock_job/input.xml) FileKlass InputXml
# [INFO] 2014-02-05 16:33:18,892 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 74 file InputXml to FileNode(74, /tmp/mock_job/input.xml) FileKlass InputXml
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 23 file PacBioToCASem to FileNode(23, /tmp/mock_job/pacBioToCA.sem) FileKlass PacBioToCASem
# [INFO] 2014-02-05 16:33:18,893 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 23 file PacBioToCASem to FileNode(23, /tmp/mock_job/pacBioToCA.sem) FileKlass PacBioToCASem
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 66 file FilterSubreadSummaryCsv to FileNode(66, /tmp/mock_job/filter_subread_summary.csv) FileKlass FilterSubreadSummaryCsv
# [INFO] 2014-02-05 16:33:18,893 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 66 file FilterSubreadSummaryCsv to FileNode(66, /tmp/mock_job/filter_subread_summary.csv) FileKlass FilterSubreadSummaryCsv
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 27 file MovieFofn to FileNode(27, /tmp/mock_job/input.fofn) FileKlass MovieFofn
# [INFO] 2014-02-05 16:33:18,893 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 27 file MovieFofn to FileNode(27, /tmp/mock_job/input.fofn) FileKlass MovieFofn
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 72 file FilterSubreadReport to FileNode(72, /tmp/mock_job/filter_reports_filter_subread_stats.json) FileKlass FilterSubreadReport
# [INFO] 2014-02-05 16:33:18,894 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 72 file FilterSubreadReport to FileNode(72, /tmp/mock_job/filter_reports_filter_subread_stats.json) FileKlass FilterSubreadReport
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 15 file ReferenceEntryType to FileNode(15, /Users/mkocher/MOCK_SEYMOUR_HOME/common/references/ecoli_k12_MG1655) FileKlass ReferenceEntryType
# [INFO] 2014-02-05 16:33:18,894 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 15 file ReferenceEntryType to FileNode(15, /Users/mkocher/MOCK_SEYMOUR_HOME/common/references/ecoli_k12_MG1655) FileKlass ReferenceEntryType
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 60 file MappingCoverageReport to FileNode(60, /tmp/mock_job/mapping_coverage_report.json) FileKlass MappingCoverageReport
# [INFO] 2014-02-05 16:33:18,895 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 60 file MappingCoverageReport to FileNode(60, /tmp/mock_job/mapping_coverage_report.json) FileKlass MappingCoverageReport
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 21 file AssemblySingletonFasta to FileNode(21, /tmp/mock_job/celera-assembler.singleton.fasta) FileKlass AssemblySingletonFasta
# [INFO] 2014-02-05 16:33:18,895 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 21 file AssemblySingletonFasta to FileNode(21, /tmp/mock_job/celera-assembler.singleton.fasta) FileKlass AssemblySingletonFasta
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 17 file PacBioToCASemFrgLoaded to FileNode(17, /tmp/mock_job/pacBioToCAFrgLoad.sem) FileKlass PacBioToCASemFrgLoaded
# [INFO] 2014-02-05 16:33:18,896 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 17 file PacBioToCASemFrgLoaded to FileNode(17, /tmp/mock_job/pacBioToCAFrgLoad.sem) FileKlass PacBioToCASemFrgLoaded
# INFO:pbsmrtpipe.dag:Resolving MetaFile MetaFile id 76 file MovieOverviewJsonReport to FileNode(76, /tmp/mock_job/movie_overview_report.json) FileKlass MovieOverviewJsonReport
# [INFO] 2014-02-05 16:33:18,896 [pbsmrtpipe.dag _resolve_file_node 294] Resolving MetaFile MetaFile id 76 file MovieOverviewJsonReport to FileNode(76, /tmp/mock_job/movie_overview_report.json) FileKlass MovieOverviewJsonReport
# DEBUG:pbsmrtpipe.dag:{1: FilteredSubreadsFasta file_id 1
# /tmp/mock_job/filtered_subreads.fasta verified False, 2: FilteredLongReadsFasta file_id 2
# /tmp/mock_job/"filtered_longreads.fasta" verified False, 4: BlasrM4 file_id 4
# /tmp/mock_job/seeds.m4 verified False, 5: BlasrM4Fofn file_id 5
# /tmp/mock_job/seeds.m4.fofn verified False, 7: FilteredBlasrM4 file_id 7
# /tmp/mock_job/seeds.m4.filter verified False, 9: CorrectedFasta file_id 9
# /tmp/mock_job/corrected.fasta verified False, 10: CorrectedFastq file_id 10
# /tmp/mock_job/corrected.fastq verified False, 12: PreAssemblerReport file_id 12
# /tmp/mock_job/preassembler_report.json verified False, 14: AssemblyScfFasta file_id 14
# /tmp/mock_job/celera-assembler.scf.fasta verified False, 15: ReferenceEntryType file_id 15
# /Users/mkocher/MOCK_SEYMOUR_HOME/common/references/ecoli_k12_MG1655 verified False, 17: PacBioToCASemFrgLoaded file_id 17
# /tmp/mock_job/pacBioToCAFrgLoad.sem verified False, 18: RunCeleraAssemblerSpec file_id 18
# /tmp/mock_job/runCA.spec verified False, 19: CeleraAssemblerAsm file_id 19
# /tmp/mock_job/celera-assembler.asm verified False, 20: AssemblyDegFasta file_id 20
# /tmp/mock_job/celera-assembler.deg.fasta verified False, 21: AssemblySingletonFasta file_id 21
# /tmp/mock_job/celera-assembler.singleton.fasta verified False, 23: PacBioToCASem file_id 23
# /tmp/mock_job/pacBioToCA.sem verified False, 25: CorrectedReadsFrg file_id 25
# /tmp/mock_job/corrected.frg verified False, 27: MovieFofn file_id 27
# /tmp/mock_job/input.fofn verified False, 28: FilteredRegionFofn file_id 28
# /tmp/mock_job/filtered_region.fofn verified False, 29: AlignedCmph5 file_id 29
# /tmp/mock_job/aligned_reads.cmp.h5 verified False, 31: SortedAlignedCmph5 file_id 31
# /tmp/mock_job/aligned_reads.cmp.h5 verified False, 33: ChemistryMappingXml file_id 33
# /tmp/mock_job/chemistry_mapping.xml verified False, 34: SortedAlignedCmph5WithChemistry file_id 34
# /tmp/mock_job/aligned_reads.cmp.h5 verified False, 36: MappingSam file_id 36
# /tmp/mock_job/aligned_reads.sam verified False, 37: MappingBam file_id 37
# /tmp/mock_job/aligned_reads.bam verified False, 39: UnmappedSubreadsFasta file_id 39
# /tmp/mock_job/unmapped_subreads.fasta verified False, 41: MappingAlignmentSummaryGff file_id 41
# /tmp/mock_job/alignment_summary.gff verified False, 43: MappingCoverageBed file_id 43
# /tmp/mock_job/coverage.bed verified False, 45: PolishedCorrectionsGff file_id 45
# /tmp/mock_job/corrections.gff verified False, 46: PolishedAssemblyFasta file_id 46
# /tmp/mock_job/polished_assembly.fasta verified False, 47: PolishedAssemblyFastqGzipped file_id 47
# /tmp/mock_job/polished_assembly.fastq.gz verified False, 49: PolishedAlignmentGff file_id 49
# /tmp/mock_job/alignment_summary.gff verified False, 50: PolishedAlignmentWithVariantsGff file_id 50
# /tmp/mock_job/alignment_summary.gff verified False, 52: VariantsReport file_id 52
# /tmp/mock_job/variants_report.json verified False, 54: PolishedTopCorrectionsReport file_id 54
# /tmp/mock_job/top_corrections_report.json verified False, 56: PolishedAssemblyReport file_id 56
# /tmp/mock_job/corrections.json verified False, 58: MappingStatsReport file_id 58
# /tmp/mock_job/mapping_stats_report.json verified False, 60: MappingCoverageReport file_id 60
# /tmp/mock_job/mapping_coverage_report.json verified False, 62: FilterSummaryCsv file_id 62
# /tmp/mock_job/filter_summary.csv verified False, 64: FilteredSubreadsFastq file_id 64
# /tmp/mock_job/filtered_subreads.fastq verified False, 66: FilterSubreadSummaryCsv file_id 66
# /tmp/mock_job/filter_subread_summary.csv verified False, 68: FilterJsonReport file_id 68
# /tmp/mock_job/filter_report.json verified False, 70: FilterLoadingReport file_id 70
# /tmp/mock_job/filter_reports_loading.json verified False, 72: FilterSubreadReport file_id 72
# /tmp/mock_job/filter_reports_filter_subread_stats.json verified False, 74: InputXml file_id 74
# /tmp/mock_job/input.xml verified False, 76: MovieOverviewJsonReport file_id 76
# /tmp/mock_job/movie_overview_report.json verified False, 79: AdapterJsonReport file_id 79
# /tmp/mock_job/adapter_report.json verified False}
# [DEBUG] 2014-02-05 16:33:18,897 [pbsmrtpipe.dag build_resolved_graph 307] {1: FilteredSubreadsFasta file_id 1
# /tmp/mock_job/filtered_subreads.fasta verified False, 2: FilteredLongReadsFasta file_id 2
# /tmp/mock_job/"filtered_longreads.fasta" verified False, 4: BlasrM4 file_id 4
# /tmp/mock_job/seeds.m4 verified False, 5: BlasrM4Fofn file_id 5
# /tmp/mock_job/seeds.m4.fofn verified False, 7: FilteredBlasrM4 file_id 7
# /tmp/mock_job/seeds.m4.filter verified False, 9: CorrectedFasta file_id 9
# /tmp/mock_job/corrected.fasta verified False, 10: CorrectedFastq file_id 10
# /tmp/mock_job/corrected.fastq verified False, 12: PreAssemblerReport file_id 12
# /tmp/mock_job/preassembler_report.json verified False, 14: AssemblyScfFasta file_id 14
# /tmp/mock_job/celera-assembler.scf.fasta verified False, 15: ReferenceEntryType file_id 15
# /Users/mkocher/MOCK_SEYMOUR_HOME/common/references/ecoli_k12_MG1655 verified False, 17: PacBioToCASemFrgLoaded file_id 17
# /tmp/mock_job/pacBioToCAFrgLoad.sem verified False, 18: RunCeleraAssemblerSpec file_id 18
# /tmp/mock_job/runCA.spec verified False, 19: CeleraAssemblerAsm file_id 19
# /tmp/mock_job/celera-assembler.asm verified False, 20: AssemblyDegFasta file_id 20
# /tmp/mock_job/celera-assembler.deg.fasta verified False, 21: AssemblySingletonFasta file_id 21
# /tmp/mock_job/celera-assembler.singleton.fasta verified False, 23: PacBioToCASem file_id 23
# /tmp/mock_job/pacBioToCA.sem verified False, 25: CorrectedReadsFrg file_id 25
# /tmp/mock_job/corrected.frg verified False, 27: MovieFofn file_id 27
# /tmp/mock_job/input.fofn verified False, 28: FilteredRegionFofn file_id 28
# /tmp/mock_job/filtered_region.fofn verified False, 29: AlignedCmph5 file_id 29
# /tmp/mock_job/aligned_reads.cmp.h5 verified False, 31: SortedAlignedCmph5 file_id 31
# /tmp/mock_job/aligned_reads.cmp.h5 verified False, 33: ChemistryMappingXml file_id 33
# /tmp/mock_job/chemistry_mapping.xml verified False, 34: SortedAlignedCmph5WithChemistry file_id 34
# /tmp/mock_job/aligned_reads.cmp.h5 verified False, 36: MappingSam file_id 36
# /tmp/mock_job/aligned_reads.sam verified False, 37: MappingBam file_id 37
# /tmp/mock_job/aligned_reads.bam verified False, 39: UnmappedSubreadsFasta file_id 39
# /tmp/mock_job/unmapped_subreads.fasta verified False, 41: MappingAlignmentSummaryGff file_id 41
# /tmp/mock_job/alignment_summary.gff verified False, 43: MappingCoverageBed file_id 43
# /tmp/mock_job/coverage.bed verified False, 45: PolishedCorrectionsGff file_id 45
# /tmp/mock_job/corrections.gff verified False, 46: PolishedAssemblyFasta file_id 46
# /tmp/mock_job/polished_assembly.fasta verified False, 47: PolishedAssemblyFastqGzipped file_id 47
# /tmp/mock_job/polished_assembly.fastq.gz verified False, 49: PolishedAlignmentGff file_id 49
# /tmp/mock_job/alignment_summary.gff verified False, 50: PolishedAlignmentWithVariantsGff file_id 50
# /tmp/mock_job/alignment_summary.gff verified False, 52: VariantsReport file_id 52
# /tmp/mock_job/variants_report.json verified False, 54: PolishedTopCorrectionsReport file_id 54
# /tmp/mock_job/top_corrections_report.json verified False, 56: PolishedAssemblyReport file_id 56
# /tmp/mock_job/corrections.json verified False, 58: MappingStatsReport file_id 58
# /tmp/mock_job/mapping_stats_report.json verified False, 60: MappingCoverageReport file_id 60
# /tmp/mock_job/mapping_coverage_report.json verified False, 62: FilterSummaryCsv file_id 62
# /tmp/mock_job/filter_summary.csv verified False, 64: FilteredSubreadsFastq file_id 64
# /tmp/mock_job/filtered_subreads.fastq verified False, 66: FilterSubreadSummaryCsv file_id 66
# /tmp/mock_job/filter_subread_summary.csv verified False, 68: FilterJsonReport file_id 68
# /tmp/mock_job/filter_report.json verified False, 70: FilterLoadingReport file_id 70
# /tmp/mock_job/filter_reports_loading.json verified False, 72: FilterSubreadReport file_id 72
# /tmp/mock_job/filter_reports_filter_subread_stats.json verified False, 74: InputXml file_id 74
# /tmp/mock_job/input.xml verified False, 76: MovieOverviewJsonReport file_id 76
# /tmp/mock_job/movie_overview_report.json verified False, 79: AdapterJsonReport file_id 79
# /tmp/mock_job/adapter_report.json verified False}
# INFO:pbsmrtpipe.dag:Creating an instance of task MappingLoadChemistryTask
# [INFO] 2014-02-05 16:33:18,898 [pbsmrtpipe.dag build_resolved_graph 336] Creating an instance of task MappingLoadChemistryTask
# INFO:pbsmrtpipe.dag:Resolved options for task MappingLoadChemistryTask to {}.
# [INFO] 2014-02-05 16:33:18,899 [pbsmrtpipe.dag build_resolved_graph 342] Resolved options for task MappingLoadChemistryTask to {}.
# INFO:pbsmrtpipe.dag:MappingLoadChemistryTask inputs:2 outputs:1 nproc:1
# [INFO] 2014-02-05 16:33:18,899 [pbsmrtpipe.dag build_resolved_graph 355] MappingLoadChemistryTask inputs:2 outputs:1 nproc:1
# INFO:pbsmrtpipe.dag:Creating an instance of task MappingStatsReportTask
# [INFO] 2014-02-05 16:33:18,900 [pbsmrtpipe.dag build_resolved_graph 336] Creating an instance of task MappingStatsReportTask
# INFO:pbsmrtpipe.dag:Resolved options for task MappingStatsReportTask to {'is_internal': False, 'align_opts': False}.
# [INFO] 2014-02-05 16:33:18,901 [pbsmrtpipe.dag build_resolved_graph 342] Resolved options for task MappingStatsReportTask to {'is_internal': False, 'align_opts': False}.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-839f15aa1205> in <module>()
# ----> 1 resolved_graph = pbd.build_resolved_graph(abstract_g, inputs_d, workflow_settings)
#
# /Users/mkocher/.virtualenvs/dev_pbsmrtpipe/lib/python2.7/site-packages/pbsmrtpipe/dag.pyc in build_resolved_graph(g, inputs_d, workflow_settings)
#     351                                           tmp_files=tmp_files,
#     352                                           tmp_dirs=tmp_dirs,
# --> 353                                           options=resolved_options)
#     354
#     355         log.info(task)
#
# /Users/mkocher/.virtualenvs/dev_pbsmrtpipe/lib/python2.7/site-packages/pbsmrtpipe/model.pyc in from_io_options(cls, inputs, outputs, nproc, tmp_dirs, tmp_files, options)
#     639
#     640         return cls(inputs, outputs, nproc=nproc, tmp_files=tmp_files,
# --> 641                    tmp_dirs=tmp_dirs, options=internal_options)
#     642
#     643     def __getattr__(self, item):
#
# /Users/mkocher/.virtualenvs/dev_pbsmrtpipe/lib/python2.7/site-packages/pbsmrtpipe/model.pyc in __init__(self, inputs, outputs, nproc, tmp_dirs, tmp_files, options)
#     560                 value = options[internal_name]
#     561                 # validate option
# --> 562                 if isinstance(value, o.TYPE):
#     563                     self.workflow_settings[internal_name] = o.value(value)
#     564                 else:
#
# AttributeError: 'TaskOption' object has no attribute 'TYPE'

# %%
tb.display_networkx_graph(resolved_graph)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-c3268ba73cb9> in <module>()
# ----> 1 tb.display_networkx_graph(resolved_graph)
#
# NameError: name 'resolved_graph' is not defined

# %%
tns = resolved_graph.task_nodes()

# %%
task_klasses
# Out:
# [pbsmrtpipe.task_modules.fetch.ToFofnTask,
#  pbsmrtpipe.task_modules.fetch.OverViewTask,
#  pbsmrtpipe.task_modules.fetch.GetChemistryTask,
#  pbsmrtpipe.task_modules.fetch.AdapterReportTask,
#  pbsmrtpipe.task_modules.filter.FilterTask,
#  pbsmrtpipe.task_modules.filter.FilterSubreadsTask,
#  pbsmrtpipe.task_modules.filter.FilterSubreadSummaryTask]

# %%
tf = task_klasses[4]

# %%
fo = tf._OPTIONS['filters']

# %%
workflow_settings._settings
# Out:
# {'global.noise.data': '-77.27,0.08654,0.00121',
#  'global.reference': '/mnt/secondary-siv/references/ecoli_k12_MG1655',
#  'global.use_subreads': 'True',
#  'p_filter.filters': 'MinRL=50,MinReadScore=0.65',
#  'p_filter.trim': 'True',
#  'p_mapping.concordant': 'True',
#  'p_mapping.gff2Bed': 'True',
#  'p_mapping.loadPulsesOpts': 'bymetric',
#  'p_mapping.maxDivergence': '30',
#  'p_mapping.maxHits': '10',
#  'p_mapping.minAnchorSize': '12',
#  'p_mapping.pbalign_opts': '--seed=1 --minAccuracy=0.75 --minLength=50 --algorithmOptions="-useQuality"',
#  'p_mapping.placeRepeatsRandomly': 'True',
#  'p_mapping.pulseMetrics': 'DeletionQV,IPD,InsertionQV,PulseWidth,QualityValue,MergeQV,SubstitutionQV,DeletionTag',
#  'p_mapping.samBam': 'True'}

# %%
fo.value('MinRL=50,MinReadScore=0.65')
# Out:
# 'MinRL=50,MinReadScore=0.65'

# %%
tf.INPUTS
# Out:
# (pbsmrtpipe.resource_types.MovieFofn,)

# %%
tf.OUTPUTS
# Out:
# (pbsmrtpipe.resource_types.FilteredRegionFofn,
#  pbsmrtpipe.resource_types.FilterSummaryCsv)

# %%
movie_fofn = pbrt.MovieFofn("/path/to/movie.fofn")
rfofn = pbrt.FilteredRegionFofn("/path/to/filtered_region.fofn")
csv = pbrt.FilterSummaryCsv("/path/to/filtered_subreads.csv")

# %%
filter_task = tf([movie_fofn], [rfofn, csv], 1, trim='True', filters='MinRL=50,MinReadScore=0.65', minSubReadLength=50, readScore=0.75,use_subreads='True')

# %%
filter_task.workflow_settings
# Out:
# {'artifact_score': None,
#  'filters': 'MinRL=50,MinReadScore=0.65',
#  'maxLength': None,
#  'maxSubReadLength': None,
#  'minLength': None,
#  'minSNR': None,
#  'minSubReadLength': 50,
#  'readScore': 0.75,
#  'trim': True,
#  'use_ccs': False,
#  'use_subreads': True,
#  'whiteList': None}

# %%
print filter_task.trim
print filter_task.use_subreads
print filter_task.filters
print getattr(filter_task, 'minSubReadLength')
# Out:
# True
# True
# MinRL=50,MinReadScore=0.65
# 50

# %%
filter_task.to_cmd()
# Out:
# ['mkdir -p /path/to/filtered_regions',
#  "filter_plsh5.py --debug --filter='MinRL=50,MinReadScore=0.65,MinReadScore=0.75,MinSRL=50' --trim='True' --outputDir=/path/to/FIXME --outputSummary=/path/to/filtered_subreads.csv --outputFofn=/path/to/FIXME2 /path/to/movie.fofn"]

# %%
print filter_task.trim
# Out:
# True

# %%
filter_task._OPTIONS['trim'].from_string('True')
# Out:
# True

# %%
print getattr(filter_task, 'trim')
# Out:
# True

# %%
filter_task.resolved_options
# Out:
# {}

# %%
filter_task.supplied_options
# Out:
# {'filters': 'MinRL=50,MinReadScore=0.65',
#  'minSubReadLength': 50,
#  'readScore': 0.75,
#  'trim': 'True',
#  'use_subreads': 'True'}

# %%
filter_task.workflow_settings
# Out:
# {'artifact_score': None,
#  'filters': 'MinRL=50,MinReadScore=0.65',
#  'maxLength': None,
#  'maxSubReadLength': None,
#  'minLength': None,
#  'minSNR': None,
#  'minSubReadLength': 50,
#  'readScore': 0.75,
#  'trim': True,
#  'use_ccs': False,
#  'use_subreads': True,
#  'whiteList': None}

# %%
o = pbsmrtpipe.model.BoolOption('my_bool', default_value=True, optional=True)

# %%
o.from_string('True')
# Out:
# True
