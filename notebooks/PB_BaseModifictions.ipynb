# %%
import os
import networkx as nx
import importlib
import logging
import functools
import operator
import itertools
from collections import OrderedDict

import pbsmrtpipe.loader as pbl
import pbsmrtpipe.chunked_models as pbc
import pbsmrtpipe.dag as pbd
import pbsmrtpipe.io as pbio
import pbsmrtpipe.resource_types as pbrt
import pbsmrtpipe.utils as pbu
import pbsmrtpipe.mock

import pbsmrtpipe.task_modules
from pbsmrtpipe.resource_types import ReferenceEntryType, InputXml, MovieFofn, BaseFileType
from pbsmrtpipe.decos import validate_type
from pbsmrtpipe.model import P_Module, MetaTask, MetaFile, FileNode, TaskNode
from pbsmrtpipe.task_modules.core import ChunkedList, BaseGatherTask

import pbsmrtpipe.toolbook as tb

log = logging.getLogger()
#pbu.setup_log(log, level=logging.DEBUG)

# %%
pb_module_names = 'fetch filter filter_reports mapping mapping_reports genomic_consensus genomic_consensus_reports modification_detection motif_finder'.split()

task_klasses = pbl.load_tasks_from_pb_module_names(pb_module_names)
abstract_g = pbd.build_abstract_graph_from_task_classes(task_klasses)

# %%
tb.display_networkx_graph(abstract_g)

# %%
pbd.find_required_input_files(abstract_g)
# Out:
# [<MetaFile id 67 file MappingCmph5>,
#  <MetaFile id 1 file InputXml>,
#  <MetaFile id 52 file CoverageGff>,
#  <MetaFile id 24 file ReferenceEntryType>]

# %%
workflow_settings = pbsmrtpipe.mock.get_mapping_workflow_settings()

# %%
required_task_klasses = [i.file_klass for i in pbd.find_required_input_files(abstract_g)]
inputs_d = {i.__class__:i.path for i in pbsmrtpipe.mock.generate_mock_files_from_klasses(required_task_klasses, workflow_settings.job_output_dir)}
# Overwrite with real reference
inputs_d[ReferenceEntryType] = pbsmrtpipe.mock.get_reference_dir()
inputs_d
# Out:
# {pbsmrtpipe.resource_types.InputXml: '/tmp/mock_job/input.xml',
#  pbsmrtpipe.resource_types.MappingCmph5: '/tmp/mock_job/aligned_reads.cmp.h5',
#  pbsmrtpipe.resource_types.ReferenceEntryType: '/Users/mkocher/MOCK_SEYMOUR_HOME/common/references/ecoli_k12_MG1655',
#  pbsmrtpipe.resource_types.CoverageGff: '/tmp/mock_job/coverage.gff'}

# %%
task_klasses
# Out:
# [pbsmrtpipe.task_modules.fetch.ToFofnTask,
#  pbsmrtpipe.task_modules.fetch.OverViewTask,
#  pbsmrtpipe.task_modules.fetch.GetChemistryTask,
#  pbsmrtpipe.task_modules.fetch.AdapterReportTask,
#  pbsmrtpipe.task_modules.filter.FilterTask,
#  pbsmrtpipe.task_modules.filter.FilterSubreadsTask,
#  pbsmrtpipe.task_modules.filter.FilterSubreadSummaryTask,
#  pbsmrtpipe.task_modules.filter_reports.FilterStatsReportTask,
#  pbsmrtpipe.task_modules.filter_reports.FilterLoadingReportTask,
#  pbsmrtpipe.task_modules.filter_reports.FilterSubreadReportTask,
#  pbsmrtpipe.task_modules.mapping.MappingAlignTask,
#  pbsmrtpipe.task_modules.mapping.MappingSortTask,
#  pbsmrtpipe.task_modules.mapping.MappingLoadChemistryTask,
#  pbsmrtpipe.task_modules.mapping.MappingSamBamTask,
#  pbsmrtpipe.task_modules.mapping.MappingUnmappedTask,
#  pbsmrtpipe.task_modules.mapping.CoverageGffTask,
#  pbsmrtpipe.task_modules.mapping.GffToBedTask,
#  pbsmrtpipe.task_modules.mapping_reports.MappingStatsReportTask,
#  pbsmrtpipe.task_modules.mapping_reports.MappingCoverageReportTask,
#  pbsmrtpipe.task_modules.genomic_consensus.CallVariantsWithConsensusTask,
#  pbsmrtpipe.task_modules.genomic_consensus.MakeBedTask,
#  pbsmrtpipe.task_modules.genomic_consensus.MakeVcfTask,
#  pbsmrtpipe.task_modules.genomic_consensus.EnrichAlSummaryTask,
#  pbsmrtpipe.task_modules.genomic_consensus_reports.TopVariantsReportTask,
#  pbsmrtpipe.task_modules.genomic_consensus_reports.VariantsReportTask,
#  pbsmrtpipe.task_modules.modification_detection.WriteContigListTask,
#  pbsmrtpipe.task_modules.modification_detection.ComputeModificationsTask,
#  pbsmrtpipe.task_modules.modification_detection.AddModificationsToAlignmentSummaryTask,
#  pbsmrtpipe.task_modules.modification_detection.CopyIpdSummaryTask,
#  pbsmrtpipe.task_modules.modification_detection.ModificationReportTask,
#  pbsmrtpipe.task_modules.motif_finder.FindMotifsTask,
#  pbsmrtpipe.task_modules.motif_finder.MakeMotifGffTask,
#  pbsmrtpipe.task_modules.motif_finder.MakeMotifPlotTask]

# %%
workflow_settings
# Out:
# <WorkflowSettings nsettings:15 dir:/tmp/mock_job id:123456 >

# %%
print workflow_settings
# Out:
# WorkflowSettings Summary
#            chunked : False
#        distributed : False
#          max_slots : 8
#        max_workers : 6
#            tmp_dir : /scratch
#              nproc : 4
#             job_id : 123456
#              debug : True
#     job_output_dir : /tmp/mock_job
#   ALGO_PARAMS_PATH : /Users/mkocher/MOCK_SEYMOUR_HOME/analysis/etc/algorithm_parameters/2013-09
#     INPUT_HDF5_EXT : bas.h5

# %%
print workflow_settings.summary()
# Out:
# WorkflowSettings Summary
#            chunked : False
#        distributed : False
#          max_slots : 8
#        max_workers : 6
#            tmp_dir : /scratch
#              nproc : 4
#             job_id : 123456
#              debug : True
#     job_output_dir : /tmp/mock_job
#   ALGO_PARAMS_PATH : /Users/mkocher/MOCK_SEYMOUR_HOME/analysis/etc/algorithm_parameters/2013-09
#     INPUT_HDF5_EXT : bas.h5
#
# Module Parameters
#                  global.noise.data : -77.27,0.08654,0.00121
#                   global.reference : /mnt/secondary-siv/references/ecoli_k12_MG1655
#                global.use_subreads : True
#                   p_filter.filters : MinRL=50,MinReadScore=0.65
#                      p_filter.trim : True
#               p_mapping.concordant : True
#                  p_mapping.gff2Bed : True
#           p_mapping.loadPulsesOpts : bymetric
#            p_mapping.maxDivergence : 30
#                  p_mapping.maxHits : 10
#            p_mapping.minAnchorSize : 12
#             p_mapping.pbalign_opts : --seed=1 --minAccuracy=0.75 --minLength=50 --algorithmOptions="-useQuality"
#     p_mapping.placeRepeatsRandomly : True
#             p_mapping.pulseMetrics : DeletionQV,IPD,InsertionQV,PulseWidth,QualityValue,MergeQV,SubstitutionQV,DeletionTag
#                   p_mapping.samBam : True

# %%
pbd.find_required_input_files(abstract_g)
# Out:
# [<MetaFile id 67 file MappingCmph5>,
#  <MetaFile id 1 file InputXml>,
#  <MetaFile id 52 file CoverageGff>,
#  <MetaFile id 24 file ReferenceEntryType>]

# %%
resolved_g = pbd.build_resolved_graph(abstract_g, inputs_d, workflow_settings)

# %%
tb.display_networkx_graph(resolved_g)

# %%
print tb.pretty_print_task_klass_options(task_klasses)
# Out:
# ---------------------------------------------------
# PB module pbsmrtpipe.task_modules.fetch noptions: 0
# ---------------------------------------------------
#
# -----------------------------------------------------
# PB module pbsmrtpipe.task_modules.filter noptions: 12
# -----------------------------------------------------
# trim                    BoolOption                 True  True
# readScore               FloatOption                True  None
# maxSubReadLength        IntOption                  True  None
# use_ccs                 BoolOption                 True  False
# minSubReadLength        IntOption                  True  None
# artifact_score          ArtifactScoreOption        True  None
# minLength               IntOption                  True  None
# whiteList               StringOption               True  None
# minSNR                  IntOption                  True  None
# use_subreads            BoolOption                 True  True
# filters                 CustomFilterOption         True
# maxLength               IntOption                  True  None
#
# ------------------------------------------------------------
# PB module pbsmrtpipe.task_modules.filter_reports noptions: 0
# ------------------------------------------------------------
#
# ------------------------------------------------------
# PB module pbsmrtpipe.task_modules.mapping noptions: 20
# ------------------------------------------------------
# concordant              BoolOption                 True  False
# maxHits                 IntOption                  True  -1
# loadPulses              BoolOption                 True  True
# loadPulsesOpts          StringOption               True
# algorithm               StringChoiceOption         True  blasr
# placeRepeatsRandomly    BoolOption                 True  True
# filterAdapterOnly       BoolOption                 True  False
# pbcmph5                 BoolOption                 True  False
# pulseMetrics            StringOption               True  QualityValue,InsertionQV,DeletionQV,IPD,PulseWidth
# pyLoadPulses            BoolOption                 True  False
# minAnchorSize           IntOption                  True  -1
# useDeepSorting          BoolOption                 True  True
# maxDivergence           FloatOption                True  -1.0
# num_stats_regions       IntOption                  True  500
# align_opts              StringOption               True  None
# samReadGroups           StringOption               True  movie
# divideByAdapter         BoolOption                 True  False
# use_subreads            BoolOption                 True  True
# pbalign_opts            StringOption               False None
# noise.data              StringOption               True  None
#
# -------------------------------------------------------------
# PB module pbsmrtpipe.task_modules.mapping_reports noptions: 2
# -------------------------------------------------------------
# is_internal             TaskOption                 True  False
# align_opts              TaskOption                 True  False
#
# ---------------------------------------------------------------
# PB module pbsmrtpipe.task_modules.genomic_consensus noptions: 5
# ---------------------------------------------------------------
# minConfidence           IntOption                  True  40
# enableMapQVFilter       BoolOption                 True  True
# algorithmParamsDir      PacbioAlgoParamEnvOption   True  /Users/mkocher/MOCK_SEYMOUR_HOME/analysis/etc/algorithm_parameters/2013-09
# algorithm               StringChoiceOption         True  plurality
# minCoverage             IntOption                  True  5
#
# -----------------------------------------------------------------------
# PB module pbsmrtpipe.task_modules.genomic_consensus_reports noptions: 0
# -----------------------------------------------------------------------
#
# --------------------------------------------------------------------
# PB module pbsmrtpipe.task_modules.modification_detection noptions: 7
# --------------------------------------------------------------------
# enableMapQVFilter       BoolOption                 True  False
# computeMethylFraction   BoolOption                 True  True
# mapQvThreshold          FloatOption                True  None
# tetTreated              BoolOption                 True  False
# identifyModifications   BoolOption                 True  False
# maxLength               IntOption                  True  -1
# algorithmParamsDir      PacbioAlgoParamEnvOption   True  /Users/mkocher/MOCK_SEYMOUR_HOME/analysis/etc/algorithm_parameters/2013-09
#
# ----------------------------------------------------------
# PB module pbsmrtpipe.task_modules.motif_finder noptions: 1
# ----------------------------------------------------------
# minScore                IntOption                  True  30
